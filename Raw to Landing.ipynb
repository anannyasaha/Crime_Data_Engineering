# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
# Out:
# StatementMeta(, b01347a5-ee50-49db-8d8d-bca71e21ec56, 3, Finished, Available, Finished)

# %%
abfs_path='abfss://b0cceb94-d226-4dbd-a75b-789c5defa0a2@onelake.dfs.fabric.microsoft.com/f5ac5edb-ff4b-4a7b-ab7c-1b4182e0d30b/Files/Raw'
# Out:
# StatementMeta(, b01347a5-ee50-49db-8d8d-bca71e21ec56, 4, Finished, Available, Finished)

# %%
file_name='crime_data.csv'
processed_date="2025-11-11"
# Out:
# StatementMeta(, b01347a5-ee50-49db-8d8d-bca71e21ec56, 5, Finished, Available, Finished)

# %%
full_path=f"{abfs_path}/{file_name}"
print(full_path)
# Out:
# StatementMeta(, b01347a5-ee50-49db-8d8d-bca71e21ec56, 6, Finished, Available, Finished)
# abfss://b0cceb94-d226-4dbd-a75b-789c5defa0a2@onelake.dfs.fabric.microsoft.com/f5ac5edb-ff4b-4a7b-ab7c-1b4182e0d30b/Files/Raw/crime_data.csv

# %%
df=spark.read.csv(path=full_path,header=True,inferSchema=True)
display(df)
# Out:
# StatementMeta(, b01347a5-ee50-49db-8d8d-bca71e21ec56, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 191e18e4-f2ae-4a92-b4bb-1d9033764ff2)

# %%
from pyspark.sql.functions import lit
df_new=df.withColumn("Processing_date",lit(processed_date))
df_new.write.format('csv').option("header","True").mode("append").partitionBy("Processing_date").save('abfss://b0cceb94-d226-4dbd-a75b-789c5defa0a2@onelake.dfs.fabric.microsoft.com/f5ac5edb-ff4b-4a7b-ab7c-1b4182e0d30b/Files/Landing')
# Out:
# StatementMeta(, b01347a5-ee50-49db-8d8d-bca71e21ec56, 8, Finished, Available, Finished)
